# %% [markdown]
# <div style="text-align:center; color: blue"><h1>Sprint 5: Hipotesis Testing</h1></div>

# %%
import pandas as pd

# %%
#importamos los datos
df = pd.read_csv('Lligues_europees_UEFA.csv', encoding='ISO-8859-1', sep=';')
#convertimos a utf-8 para que no haya problemas con los acentos
df = df.apply(lambda x: x.astype(str).str.encode('utf-8').str.decode('utf-8'))
df
# Out:
#     Rk            Squad Country LgRk  MP   W   D   L  GF  GA  ... Pts Pts/G
# 0    1  Manchester City     ENG    1  37  28   6   3  96  24  ...  90  2.43  \
# 1    2        Liverpool     ENG    2  36  26   8   2  89  24  ...  86  2.39
# 2    3      Real Madrid     ESP    1  37  26   7   4  80  31  ...  85   2.3
# 3    4    Bayern Munich     GER    1  34  24   5   5  97  37  ...  77  2.26
# 4    5        Paris S-G     FRA    1  37  25   8   4  85  36  ...  83  2.24
# ..  ..              ...     ...  ...  ..  ..  ..  ..  ..  ..  ...  ..   ...
# 93  94         Bordeaux     FRA   20  37   5  13  19  48  89  ...  28  0.76
# 94  95          Venezia     ITA   20  37   6   8  23  34  69  ...  26   0.7
# 95  96          Watford     ENG   19  37   6   5  26  33  75  ...  23  0.62
# 96  97     Norwich City     ENG   20  37   5   7  25  23  79  ...  22  0.59
# 97  98   Greuther Fürth     GER   18  34   3   9  22  28  82  ...  18  0.53
#
# ...

# %% [markdown]
# **EJERCICIO 1**: Descarga el dataset adjunto de datos oficiales de la UEFA y selecciona un atributo del conjunto de datos. Calcula el p-valor y di si rechaza la hipótesis nula cogiendo un alfa de 5%.

# %%
#calculamos el p-value y di si rechaza la hipotesis nula o no con un alpha de 0.05
from scipy.stats import chi2_contingency
chi2_contingency(pd.crosstab(df['LgRk'], df['Pts']))
# Out:
# Chi2ContingencyResult(statistic=1098.0900000000001, pvalue=0.0023538366636144587, dof=969, expected_freq=array([[0.05102041, 0.05102041, 0.05102041, ..., 0.05102041, 0.05102041,
#         0.05102041],
#        [0.05102041, 0.05102041, 0.05102041, ..., 0.05102041, 0.05102041,
#         0.05102041],
#        [0.05102041, 0.05102041, 0.05102041, ..., 0.05102041, 0.05102041,
#         0.05102041],
#        ...,
#        [0.05102041, 0.05102041, 0.05102041, ..., 0.05102041, 0.05102041,
#         0.05102041],
#        [0.05102041, 0.05102041, 0.05102041, ..., 0.05102041, 0.05102041,
#         0.05102041],
#        [0.05102041, 0.05102041, 0.05102041, ..., 0.05102041, 0.05102041,
#         0.05102041]]))
